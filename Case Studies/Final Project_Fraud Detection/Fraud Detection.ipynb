# %%
#importing dependencies
import numpy as np
import pandas as pd # We are creating dataframes, dataframes are structured tables
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv("creditcard.csv")

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# Here the time is in seconds
# Class:0 means transaction is legit
# Class:1 means transaction is fraud

df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
# check missing values
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# Distribution of legit and fraud transaction
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
# So it means 284315 are legit transaction and 492 transaction are fraud, the data is very imbalance here.
#separating data for analysis

legit=df[df.Class==0] # all legit rows will be stored in 'legit' variable
fraud=df[df.Class==1] # all fraud rows will be stored in 'fraud' variable

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
# statistical measures of data
legit.Amount.describe()
# count describing number of data points we have (rows)
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
# 25% (percentile) of transactions are less than this 5.650000$
# 50% of transactions are less than this 22.000000$
# 75% of transactions are less than this 77.050000$

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# Compare the values for both transaction
df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
# Handling imbalance data using Undersampling (randomsampling)
#Build a sample dataset containing similar distribution of  normal and fraud  tranaction

legit_sample=legit.sample(n=492) # it will select random 492 legit datapoints
#The sample() method returns a list with a specified number of randomly selected items from a sequence.
#This method does not change the original sequence.

# %%
 # Concatenating both 492 legit and fraud transactions
new_dataset=pd.concat([legit_sample,fraud],axis=0) #axis=0 means all 492 dataframe values will be added 1 by 1 below the the legit sample
#axis=1 values will be added column wise.

# %%
new_dataset.head()  # these are random picked values
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 281719  170377.0  1.712766 -0.999677  0.434815  1.630471 -0.857059  1.603093
# 125958   77876.0  0.850054 -1.201491 -0.237813 -0.607297 -0.627241  0.100217
# 265515  161918.0  2.209591 -1.455303 -0.348908 -1.470320 -1.639111 -0.688935
# 233407  147551.0 -0.966747 -0.120078  1.641515 -0.832179  1.098261 -0.558332
# 76127    56407.0 -1.105934  0.983702  1.009055 -1.229044  0.342484 -0.814177
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 281719 -1.358942  0.473048  2.314411  ...  0.136381  0.788751 -0.013463
# 125958 -0.097422  0.010931 -1.379790  ... -0.196874 -0.551026 -0.103988
# 265515 -1.294577 -0.171065 -1.065085  ... -0.379878 -0.632614  0.434344
# 233407  0.082571 -0.062048  0.283259  ...  0.196744  0.677015 -0.148728
# 76127   0.958984 -0.099131 -0.426496  ... -0.353894 -1.211449 -0.015329
#
# ...

# %%
new_dataset.tail() # these are the fraud transaction which we are having from starting, these are added below legit transaction
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
new_dataset['Class'].value_counts()
# Now we have uniformly distribute data
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      96869.648374 -0.014050  0.045751 -0.019069  0.017601 -0.102197
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.068394 -0.055127 -0.062839 -0.028127  ...  0.062960 -0.045275
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.031497  0.001705 -0.056565  0.036812 -0.040060 -0.030984 -0.002055
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       92.162602
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
# Splitting into data into features & target
X=new_dataset.drop(columns='Class',axis=1)
Y=new_dataset['Class']
print(X)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 281719  170377.0  1.712766 -0.999677  0.434815  1.630471 -0.857059  1.603093
# 125958   77876.0  0.850054 -1.201491 -0.237813 -0.607297 -0.627241  0.100217
# 265515  161918.0  2.209591 -1.455303 -0.348908 -1.470320 -1.639111 -0.688935
# 233407  147551.0 -0.966747 -0.120078  1.641515 -0.832179  1.098261 -0.558332
# 76127    56407.0 -1.105934  0.983702  1.009055 -1.229044  0.342484 -0.814177
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
print(Y)
# Out:
# 281719    0
# 125958    0
# 265515    0
# 233407    0
# 76127     0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %%
# Splitting features and target in training and testing 
X_train,X_test,Y_train,Y_test = train_test_split(X, Y, test_size=0.2,stratify=Y,random_state=2) # 3 means data will be splitted in different way, when running

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (984, 30) (787, 30) (197, 30)

# %%
print(Y.shape,Y_train.shape,Y_test.shape)
# Out:
# (984,) (787,) (197,)

# %%
# Training model using Logistic regression: because for binary classification
from sklearn.linear_model import LogisticRegression
model=LogisticRegression() # loading 1 instance of logistic regression
# Training logistic regression model with training data
# for training we use fit() method
model.fit(X_train,Y_train) # X_train contains all the features data, Y_train containing all the classes corresponding to the feature data
# Out:
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# Model Evaluation
# first find accuracy score on training data
from sklearn.metrics import accuracy_score
X_train_prediction=model.predict(X_train)
training_data_accuracy=accuracy_score(X_train_prediction,Y_train) # Comparing values predicted by model on X_train with the actual values in Y_train

# %%
print("Accuracy of Logistic Regression on training data:\n",training_data_accuracy)
# Out:
# Accuracy of Logistic Regression on training data:
#  0.9466327827191868

# %%
print(df.columns)
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv("creditcard.csv")

x = df['Time']
y = df['Amount']

plt.figure(figsize=(10, 6))
plt.scatter(x, y, alpha=0.5)
plt.title('Scatter Plot of Transaction Amount vs. Time')
plt.xlabel('Time (seconds)')
plt.ylabel('Amount ($)')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['Time'], bins=50, edgecolor='black', alpha=0.7)
plt.title('Histogram of Transaction Time')
plt.xlabel('Time (seconds)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('creditcard.csv')  
class_counts = df['Class'].value_counts()
plt.figure(figsize=(8, 6))
sns.barplot(x=class_counts.index, y=class_counts.values, alpha=0.75)
plt.title('Bar Plot of Transaction Class')
plt.xlabel('Class')
plt.ylabel('Number of Transactions')
plt.xticks(ticks=[0, 1], labels=['Non-Fraudulent', 'Fraudulent'])
plt.grid(axis='y')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('creditcard.csv')  # Load your dataset here
class_counts = df['Class'].value_counts()

plt.figure(figsize=(8, 6))
plt.pie(class_counts, labels=['Non-Fraudulent', 'Fraudulent'], autopct='%1.1f%%', startangle=140, colors=['skyblue', 'lightcoral'], explode=(0.1, 0), shadow=True)
plt.title('Pie Chart of Transaction Class Distribution')
plt.axis('equal')  
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('creditcard.csv')  
plt.figure(figsize=(8, 6))
sns.countplot(x='Class', data=df, palette='Set2')
plt.title('Count Plot of Transaction Class')
plt.xlabel('Class')
plt.ylabel('Number of Transactions')
plt.xticks(ticks=[0, 1], labels=['Non-Fraudulent', 'Fraudulent'])
plt.grid(axis='y')
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_10252\4141188744.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Class', data=df, palette='Set2')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('creditcard.csv')  
numeric_columns = df[['V1', 'V2', 'V3', 'V4', 'V5', 'V10', 'V11', 'V12', 'V14', 'V16', 'Amount']]
correlation_matrix = numeric_columns.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Heatmap of Credit Card Fraud Data')
plt.show()
