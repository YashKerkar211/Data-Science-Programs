# %% [markdown]
# <a href="https://colab.research.google.com/github/YashKerkar211/Data-Science-Programs/blob/main/Case%20Studies/BlackFriday/BlackFriday.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

# %%
train_df.head()
train_df.describe()
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
# Data cleaning starts
print(train_df.isnull().sum())
print()
print(test_df.isnull().sum())
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64
#
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2             72344
# Product_Category_3            162562
# dtype: int64

# %%
# Impute missing values in training data
train_df.loc[:, 'Product_Category_2'] = train_df['Product_Category_2'].fillna(train_df['Product_Category_2'].median())
train_df.loc[:, 'Product_Category_3'] = train_df['Product_Category_3'].fillna(train_df['Product_Category_3'].median())

# Impute missing values in testing data
test_df.loc[:, 'Product_Category_2'] = test_df['Product_Category_2'].fillna(test_df['Product_Category_2'].median())
test_df.loc[:, 'Product_Category_3'] = test_df['Product_Category_3'].fillna(test_df['Product_Category_3'].median())

# %%
print(train_df.isnull().sum())
print()
print(test_df.isnull().sum())
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64
#
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le_gen=LabelEncoder()
le_age=LabelEncoder()
le_city=LabelEncoder()
train_df['Gender']=le_age.fit_transform(train_df['Gender'])
train_df['Age']=le_age.fit_transform(train_df['Age'])
train_df['City_Category']=le_age.fit_transform(train_df['City_Category'])

# %%
print(train_df.head())
# Out:
#    User_ID Product_ID  Gender  Age  Occupation  City_Category  \
# 0  1000001  P00069042       0    0          10              0
# 1  1000001  P00248942       0    0          10              0
# 2  1000001  P00087842       0    0          10              0
# 3  1000001  P00085442       0    0          10              0
# 4  1000002  P00285442       1    6          16              2
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 9.0                14.0    8370.0
# 1                 6.0                14.0   15200.0
# ...

# %%
print(test_df.head())
# Out:
#    User_ID Product_ID  Gender  Age  Occupation  City_Category  \
# 0  1000004  P00128942       1    4           7              1
# 1  1000009  P00113442       1    2          17              2
# 2  1000010  P00288442       0    3           1              1
# 3  1000010  P00145342       0    3           1              1
# 4  1000011  P00053842       0    2           1              2
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
#
#    Product_Category_2  Product_Category_3
# 0                11.0                14.0
# 1                 5.0                14.0
# 2                14.0                14.0
# ...

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
le_gen=LabelEncoder()
le_age=LabelEncoder()
le_city=LabelEncoder()
df=pd.read_csv("test.csv")
test_df['Gender']=le_age.fit_transform(test_df['Gender'])
test_df['Age']=le_age.fit_transform(test_df['Age'])
test_df['City_Category']=le_age.fit_transform(test_df['City_Category'])

# %%
print(test_df.head())
# Out:
#    User_ID Product_ID  Gender  Age  Occupation  City_Category  \
# 0  1000004  P00128942       1    4           7              1
# 1  1000009  P00113442       1    2          17              2
# 2  1000010  P00288442       0    3           1              1
# 3  1000010  P00145342       0    3           1              1
# 4  1000011  P00053842       0    2           1              2
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
#
#    Product_Category_2  Product_Category_3
# 0                11.0                14.0
# 1                 5.0                14.0
# 2                14.0                14.0
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
sns.boxplot(train_df['Purchase'])
plt.title('Boxplot of Purchase Amount in Training Dataset')
plt.xlabel('Purchase Amount')
plt.show()

# %%
print(train_df.columns)
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
print(test_df.columns)
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3'],
#       dtype='object')

# %%
X = train_df.drop(['User_ID','Product_ID','Gender','Age','Occupation','City_Category','Stay_In_Current_City_Years', 'Marital_Status'], axis=1)
X = X.drop('Purchase', axis=1)
Y = train_df['Purchase']
print(X)
print(Y)
# Out:
#         Product_Category_1  Product_Category_2  Product_Category_3
# 0                        3                 9.0                14.0
# 1                        1                 6.0                14.0
# 2                       12                 9.0                14.0
# 3                       12                14.0                14.0
# 4                        8                 9.0                14.0
# ...                    ...                 ...                 ...
# 550063                  20                 9.0                14.0
# 550064                  20                 9.0                14.0
# 550065                  20                 9.0                14.0
# 550066                  20                 9.0                14.0
# 550067                  20                 9.0                14.0
#
# [550068 rows x 3 columns]
# 0          8370.0
# 1         15200.0
# 2          1422.0
# 3          1057.0
# 4          7969.0
#            ...
# 550063      368.0
# ...

# %%
missing_values=X.isnull().sum()
print(missing_values)
# Out:
# Product_Category_1    0
# Product_Category_2    0
# Product_Category_3    0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(strategy='mean')
X_imputed=imputer.fit_transform(X)

#convert back to dataframes if needed
X_imputed=pd.DataFrame(X_imputed,columns=X.columns)

# %%
import pandas as pd
df=pd.read_csv('test.csv')

# %%
columns_to_drop = ['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation',
                   'City_Category', 'Stay_In_Current_City_Years', 'Marital_Status']
test_X = test_df.drop(columns=columns_to_drop)

# %%
test_X_imputed = imputer.transform(test_X)

# %%
# Converting test_X to Dataframe
test_X_imputed = pd.DataFrame(test_X_imputed, columns=test_X.columns)

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

print(train_df.isnull().sum())
print()
print(test_df.isnull().sum())

train_df['Product_Category_2'] = train_df['Product_Category_2'].fillna(train_df['Product_Category_2'].median())
train_df['Product_Category_3'] = train_df['Product_Category_3'].fillna(train_df['Product_Category_3'].median())

test_df['Product_Category_2'] = test_df['Product_Category_2'].fillna(test_df['Product_Category_2'].median())
test_df['Product_Category_3'] = test_df['Product_Category_3'].fillna(test_df['Product_Category_3'].median())

print(train_df.isnull().sum())
print()
print(test_df.isnull().sum())

le_gen = LabelEncoder()
le_age = LabelEncoder()
le_city = LabelEncoder()

train_df['Gender'] = le_gen.fit_transform(train_df['Gender'])
train_df['Age'] = le_age.fit_transform(train_df['Age'])
train_df['City_Category'] = le_city.fit_transform(train_df['City_Category'])

test_df['Gender'] = le_gen.transform(test_df['Gender'])
test_df['Age'] = le_age.transform(test_df['Age'])
test_df['City_Category'] = le_city.transform(test_df['City_Category'])

columns_to_drop = ['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category', 'Stay_In_Current_City_Years', 'Marital_Status']
X = train_df.drop(columns=columns_to_drop)
X = X.drop('Purchase', axis=1)
Y = train_df['Purchase']

imputer = SimpleImputer(strategy='mean')
X_imputed = imputer.fit_transform(X)

X_imputed = pd.DataFrame(X_imputed, columns=X.columns)

X_train, X_val, y_train, y_val = train_test_split(X_imputed, Y, test_size=0.2, random_state=42)

linear_model = LinearRegression()
linear_model.fit(X_train, y_train)

y_val_pred = linear_model.predict(X_val)

mse = mean_squared_error(y_val, y_val_pred)
print(f'Validation Mean Squared Error: {mse}')

linear_model.fit(X_imputed, Y)

test_X = test_df.drop(columns=columns_to_drop)
test_X_imputed = imputer.transform(test_X)
test_X_imputed = pd.DataFrame(test_X_imputed, columns=test_X.columns)

test_predictions = linear_model.predict(test_X_imputed)

test_predictions_df = pd.DataFrame(test_predictions, columns=['Purchase'])

submission = test_df[['User_ID', 'Product_ID']].copy()
submission['Purchase'] = test_predictions_df['Purchase']

submission.to_csv('submission.csv', index=False)
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64
#
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2             72344
# Product_Category_3            162562
# dtype: int64
# User_ID                       0
# Product_ID                    0
# ...

# %%
print(train_df.columns)
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
print(test_df.columns)
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

x = train_df['Product_Category_1']
y = train_df['Purchase']

plt.figure(figsize=(10, 6))
plt.scatter(x, y, alpha=0.5)
plt.title('Scatter Plot of Product Category 1 vs Purchase Amount')
plt.xlabel('Product Category 1')
plt.ylabel('Purchase Amount')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
purchase_data = train_df['Purchase']
plt.figure(figsize=(10, 6))
plt.hist(purchase_data, bins=30, edgecolor='black')
plt.title('Histogram of Purchase Amounts')
plt.xlabel('Purchase Amount')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

average_purchase_by_age = train_df.groupby('Age')['Purchase'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(x='Age', y='Purchase', data=average_purchase_by_age)
plt.title('Average Purchase Amount by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Average Purchase Amount')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
gender_counts = train_df['Gender'].value_counts()
plt.figure(figsize=(8, 6))
plt.pie(gender_counts, labels=['Male', 'Female'], autopct='%1.1f%%',colors=['skyblue', 'red'])
plt.title('Distribution of Gender')
plt.axis('equal')  
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
sns.countplot(x='Age', data=train_df)
plt.title('Count of Customers by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
train_df = pd.read_csv('train.csv')
numeric_cols = train_df.select_dtypes(include=['number']).columns
corr_matrix = train_df[numeric_cols].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True)
plt.title('Correlation Matrix Heatmap')
plt.show()
